# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("data.csv")   #Load our dataset

# %%
ds.head()
# Out:
#          id diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0    842302         M  ...          0.4601                  0.11890
# 1    842517         M  ...          0.2750                  0.08902
# 2  84300903         M  ...          0.3613                  0.08758
# 3  84348301         M  ...          0.6638                  0.17300
# 4  84358402         M  ...          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
print("(Rows, Columns) =", ds.shape)    #check number of rows and columns in our dataset
# Out:
# (Rows, Columns) = (569, 32)

# %%
ds.dtypes         #check types of the attributes in the dataset
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
ds.isnull().sum()        #checking null values
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
ds.duplicated().values.any()     #check duplicate values in the dataset
# Out:
# False

# %% [markdown]
# #Target attribute value counts to check class imbalance problem

# %%
print("Diagnosis-Value counts:")
print(ds['diagnosis'].value_counts())
# Out:
# Diagnosis-Value counts:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
image = sns.countplot(ds['diagnosis'])
image.set_title("Count Plot for 'diagnosis' attribute")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, "Count Plot for 'diagnosis' attribute")

# %%
print("M = ", round((212 / 569) * 100), "%")
print("B = ", round((357 / 569) * 100), "%\n")
# Out:
# M =  37 %
# B =  63 %

# %% [markdown]
# #Change categorical value to numeric value

# %%
target = {'M': 1, 'B': 0}
ds['diagnosis'] = ds['diagnosis'].map(target)

# %%
print(ds['diagnosis'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %% [markdown]
# #Calculating Correlation of the attributes:

# %%
ds.corr()
# Out:
#                                id  ...  fractal_dimension_worst
# id                       1.000000  ...                -0.029866
# diagnosis                0.039769  ...                 0.323872
# radius_mean              0.074626  ...                 0.007066
# texture_mean             0.099770  ...                 0.119205
# perimeter_mean           0.073159  ...                 0.051019
# area_mean                0.096893  ...                 0.003738
# smoothness_mean         -0.012968  ...                 0.499316
# compactness_mean         0.000096  ...                 0.687382
# concavity_mean           0.050080  ...                 0.514930
# concave points_mean      0.044158  ...                 0.368661
# symmetry_mean           -0.022114  ...                 0.438413
# fractal_dimension_mean  -0.052511  ...                 0.767297
# radius_se                0.143048  ...                 0.049559
# texture_se              -0.007526  ...                -0.045655
# ...

# %% [markdown]
# #Chosing dependent and independent variable

# %%
Y = ds['diagnosis']
X = ds.drop(['diagnosis', 'id', 'texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'texture_worst', 'smoothness_worst', 'symmetry_worst', 'fractal_dimension_worst'], axis=1)

# %% [markdown]
# #Train-Test data(80:20 method)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=5)

# %% [markdown]
# #Model Build

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
classifier = RandomForestClassifier(n_estimators=20)
classifier.fit(X_train, Y_train)
Y_pred_dt = classifier.predict(X_test)
print("Accuracy score of our model is ", accuracy_score(Y_test, Y_pred_dt))
# Out:
# Accuracy score of our model is  0.956140350877193

# %% [markdown]
# #Confusion matrix

# %%
matrix = confusion_matrix(Y_test, Y_pred_dt)
print("For Random Forest:")
print(matrix)
# Out:
# For Random Forest:
# [[65  1]
#  [ 4 44]]

# %%
import pickle

# %%
pickle.dump(classifier,open('model.pkl','wb'))
